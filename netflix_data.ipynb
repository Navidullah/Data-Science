# %% [markdown]
# <span style="color:orange;">**Netflix**!</span> <p style="font-family:arial;">What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
# You have been supplied with the dataset `netflix.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!</p>

# %% [markdown]
# <p style="font-family:arial;">Perform exploratory data analysis on the netflix_data.csv data to understand more about movies from the 1990s decade.
#
# <li style="font-family:arial;">What was the most frequent movie duration in the 1990s? Save an approximate answer as an integer called duration.</li>
#
# <li style="font-family:arial;">A movie is considered short if it is less than 90 minutes. Count the number of short action movies released in the 1990s and save this integer as short_movie_count.</li>
#
# Feel free to experiment after submitting the project!</p>

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read in the Netflix CSV as a DataFrame
df = pd.read_csv('C:/Users/RBTG/OneDrive/Desktop/Data science/data/netflix.csv')

# %%
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  "Ama Qamata, Khosi Ngema, Gail Mabalane, Thaba...   South Africa
# 2  "Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nab...            NaN
# 3                                                NaN            NaN
# 4  "Mayur More, Jitendra Kumar, Ranjan Raj, Alam ...          India
#
#              date_added  release_year rating   duration  \
# 0  "September 25, 2021"          2020  PG-13     90 min
# 1  "September 24, 2021"          2021  TV-MA  2 Seasons
# 2  "September 24, 2021"          2021  TV-MA   1 Season
# ...

# %% [markdown]
# <span style="color:orange;">What was the most frequent movie duration in the 1990s? Save an approximate answer as an integer called duration.</span>

# %%
movies_90s = df.loc[(df['release_year'] >= 1990) & (df['release_year'] <= 1999) ]
movies_90s
# Out:
#        type              title        director  \
# 7     Movie            Sankofa    Haile Gerima
# 22    Movie    Avvai Shanmughi  K.S. Ravikumar
# 24    Movie              Jeans      S. Shankar
# 26    Movie     Minsara Kanavu     Rajiv Menon
# 67  TV Show  Saved by the Bell             NaN
#
#                                                  cast  \
# 7   "Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra ...
# 22  "Kamal Hassan, Meena, Gemini Ganesan, Heera Ra...
# 24  "Prashanth, Aishwarya Rai Bachchan, Sri Lakshm...
# 26  "Arvind Swamy, Kajol, Prabhu Deva, Nassar, S.P...
# 67  "Mark-Paul Gosselaar, Tiffani Thiessen, Mario ...
#
#                                               country            date_added  \
# 7   "United States, Ghana, Burkina Faso, United Ki...  "September 24, 2021"
# 22                                                NaN  "September 21, 2021"
# 24                                              India  "September 21, 2021"
# ...

# %% [markdown]
# <h3 style='color:orange;'>Extracting the integer part of string in duration column</h3>

# %%
print(movies_90s['duration'].dtype)
movies_90s['duration'] = movies_90s['duration'].astype(str)
movies_90s['duration'] = movies_90s['duration'].str.extract(r'(\d+)').astype(float)
movies_90s = movies_90s.dropna(subset=['duration'])
movies_90s
# Out:
# object
# C:\Users\RBTG\AppData\Local\Temp\ipykernel_9192\1284640738.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_90s['duration'] = movies_90s['duration'].astype(str)
# C:\Users\RBTG\AppData\Local\Temp\ipykernel_9192\1284640738.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_90s['duration'] = movies_90s['duration'].str.extract(r'(\d+)').astype(float)
#        type              title        director  \
# 7     Movie            Sankofa    Haile Gerima
# ...

# %% [markdown]
# A movie is considered short if it is less than 90 minutes. Count the number of short action movies released in the 1990s and save this integer as short_movie_count.

# %%
short_movie = movies_90s.loc[(movies_90s['duration'] < 90.0 )]

print(len(short_movie))
colors = ['blue']  # Set the colors  for each category

sns.countplot(x='duration', data=short_movie, hue='duration', palette=colors, legend=True)

 
#sns.countplot(x='Category', data=data, palette=colors)

# Show the plot
plt.show()
# Out:
# 1

# %%
colors = ['blue', 'red']  # Set the colors  for each category

sns.countplot(x='type', data=movies_90s, hue='type', palette=colors, legend=True)

 
#sns.countplot(x='Category', data=data, palette=colors)

# Show the plot
plt.show()

# %%
duration = movies_90s['duration'].mode()

print(duration)
# Out:
# 0      9.0
# 1    125.0
# 2    147.0
# 3    161.0
# 4    166.0
# Name: duration, dtype: float64

# %%
short_movie_count = len(movies_90s.loc[(movies_90s['duration'] < 90.0)])

print(short_movie_count)
# Out:
# 1
